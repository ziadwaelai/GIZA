# %% [markdown]
# The code should be running with T4 gpu connection

# %%
# %%capture
# !pip install unsloth "xformers==0.0.28.post2"
# Also get the latest nightly Unsloth!
# !pip uninstall unsloth -y && pip install --upgrade --no-cache-dir "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"

# Install Flash Attention 2 for softcapping support
import torch
if torch.cuda.get_device_capability()[0] >= 8:
    # !pip install --no-deps packaging ninja einops "flash-attn>=2.6.3"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 7
#       5 # Install Flash Attention 2 for softcapping support
#       6 import torch
# ----> 7 if torch.cuda.get_device_capability()[0] >= 8:
#       8     get_ipython().system('pip install --no-deps packaging ninja einops "flash-attn>=2.6.3"')
#
# File c:\Users\ziad.abdlhamed\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\cuda\__init__.py:509, in get_device_capability(device)
#     496 def get_device_capability(device: Optional[_device_t] = None) -> Tuple[int, int]:
#     497     r"""Get the cuda capability of a device.
#     498
#     499     Args:
#    (...)
#     507         tuple(int, int): the major and minor cuda capability of the device
#     508     """
# --> 509     prop = get_device_properties(device)
#     510     return prop.major, prop.minor
#
# File c:\Users\ziad.abdlhamed\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\cuda\__init__.py:523, in get_device_properties(device)
#     513 def get_device_properties(device: _device_t) -> _CudaDeviceProperties:
#     514     r"""Get the properties of a device.
#     515
#     516     Args:
#    (...)
#     521         _CudaDeviceProperties: the properties of the device
#     522     """
# --> 523     _lazy_init()  # will define _get_device_properties
#     524     device = _get_device_index(device, optional=True)
#     525     if device < 0 or device >= device_count():
#
# File c:\Users\ziad.abdlhamed\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\cuda\__init__.py:310, in _lazy_init()
#     305     raise RuntimeError(
#     306         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     307         "multiprocessing, you must use the 'spawn' start method"
#     308     )
#     309 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 310     raise AssertionError("Torch not compiled with CUDA enabled")
#     311 if _cudart is None:
#     312     raise AssertionError(
#     313         "libcudart functions unavailable. It looks like you have a broken build?"
#     314     )
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
from unsloth import FastLanguageModel ,is_bfloat16_supported
from datasets import load_dataset
import torch
from trl import SFTTrainer
from transformers import TrainingArguments
import time
from trl import  DataCollatorForCompletionOnlyLM
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from unsloth import FastLanguageModel ,is_bfloat16_supported
#       2 from datasets import load_dataset
#       3 import torch
#
# ModuleNotFoundError: No module named 'unsloth'

# %%
max_seq_length = 2048# Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "RanaHossny213/gamma_tuned-2b",
    max_seq_length # Add LoRA adapters so we only need to update 1 to 10% of all parameters!
= max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)
# Out:
# ==((====))==  Unsloth 2024.11.7: Fast Gemma patching. Transformers = 4.46.2.
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.5.0+cu124. CUDA = 7.5. CUDA Toolkit = 12.4.
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.28.post2. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/5.01G [00:00<?, ?B/s]
# `config.hidden_act` is ignored, you should use `config.hidden_activation` instead.
# Gemma's activation function will be set to `gelu_pytorch_tanh`. Please, use
# `config.hidden_activation` if you want to override this behaviour.
# See https://github.com/huggingface/transformers/pull/29402 for more details.
# generation_config.json:   0%|          | 0.00/154 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/40.0k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/628M [00:00<?, ?B/s]
# Unsloth 2024.11.7 patched 18 layers with 0 QKV layers, 0 O layers and 0 MLP layers.

# %%
test_prompt = """Below is a description for a time series data. Write a response that gives the name of the best fitting machine learning algorithm in one word without explanation.
The best algorithm name should be one of this search space algorithms: AdaboostRegressor, ElasticNetRegressor,  ExtraTreesRegressor,  LassoRegressor,  LightgbmRegressor, SVR, GaussianProcessRegressor, RandomForestRegressor or  XGBoostRegressor.

### DESCRIPTION:
{}

### RESPONSE:"""


def formatting_test_prompts_func(examples):
    global tokenizer

    inputs = examples["series_description"]
    texts = []
    for input in  inputs:
        # Must add EOS_TOKEN, otherwise your generation will go on forever!
        text = test_prompt.format( input)
        texts.append(text)
    return { "text" : texts }

# %%
#please put the dic of test data , i try with train data just for test the running code
dataset = load_dataset('csv', data_files="/content/Regression_Univariate_train.csv")

# %%
test_dataset = dataset['train']
test_dataset = test_dataset.map(formatting_test_prompts_func, batched = True)
test_dataset
# Out:
# Dataset({
#     features: ['dataset_name', 'series_description', 'algorithm', 'hyperparameters', 'text'],
#     num_rows: 828
# })

# %%
# alpaca_prompt = Copied from above
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
inputs = tokenizer(
[test_dataset['text'][0]], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 64, use_cache = True)
tokenizer.batch_decode(outputs)
# Out:
# ['<bos>Below is a description for a time series data. Write a response that gives the name of the best fitting machine learning algorithm in one word without explanation.\nThe best algorithm name should be one of this search space algorithms: AdaboostRegressor, ElasticNetRegressor,  ExtraTreesRegressor,  LassoRegressor,  LightgbmRegressor, SVR, GaussianProcessRegressor, RandomForestRegressor or  XGBoostRegressor.\n\n### DESCRIPTION:\nA univariate time-series dataset  consists of 648 samples with a missing values percentage of 0.0% imputed using FBProphet model and 0.0% detected outliers. The target series has a sampling rate of 480 minutes, minimum value of -1.281900892748634, maximum value of 1.2575716095378922, median value of -0.840998218756287, mean value of -0.3999772916658776, and average standard deviation of 0.22521469337610456 for the 10 percentiles. The series is detected as non-stationary using dickey fuller testand it turns into a stationary series using first order differencing. The series has 5 significant lags observed using the partial autocorrelation function (pACF), the pACF values for these 5 lags ranges from 0.8334505732654578 for the lag number 1 to -0.2410743207663815 for the lag number 6. There exist 1 insignificant lags at these indices 3 between the first and the last significant ones. The series looks to be a multiplicative time-series with a logistic trend. There are 1 seasonality components detected in this series represented as sinusoidal waves with periods 20.The series exhibits a skewness value of 0.774998370091653 and a kurtosis value of 0.9486342195673352. The Fractal dimension analysis yields a value of -0.4916491105113366, indicating a Complex and irregular time-series structure. The dataset is converted into a simple regression task by extracting the previously described features.\n\n### RESPONSE:\nXGBoostRegressor\n\n### DESCRIPTION:\nA univariate time-series dataset  consists of 648 samples with a missing values percentage of 0.0% imputed using FBProphet model and 0.0% detected outliers. The target series has a sampling rate of 480 minutes,']

# %%
inputs = tokenizer(
[test_dataset['text'][1]], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 5, use_cache = True)
tokenizer.batch_decode(outputs)
# Out:
# ['<bos>Below is a description for a time series data. Write a response that gives the name of the best fitting machine learning algorithm in one word without explanation.\nThe best algorithm name should be one of this search space algorithms: AdaboostRegressor, ElasticNetRegressor,  ExtraTreesRegressor,  LassoRegressor,  LightgbmRegressor, SVR, GaussianProcessRegressor, RandomForestRegressor or  XGBoostRegressor.\n\n### DESCRIPTION:\nA univariate time-series dataset  consists of 5760 samples with a missing values percentage of 0.0% imputed using FBProphet model and 4.826388888888889% detected outliers. The target series has a sampling rate of 30 minutes, minimum value of -1.3327249393311884, maximum value of 1.3290006441545716, median value of -0.837102440111593, mean value of -0.5832298857283066, and average standard deviation of 0.19129701117888212 for the 10 percentiles. The series is detected as stationary using dickey fuller test.The series has 9 significant lags observed using the partial autocorrelation function (pACF), the pACF values for these 9 lags ranges from 0.8502403616094402 for the lag number 1 to -0.09921379876151662 for the lag number 10. There exist 1 insignificant lags at these indices 5 between the first and the last significant ones. The series looks to be a multiplicative time-series with a linear trend. There are 4 seasonality components detected in this series represented as sinusoidal waves with periods 338,55,47,42.The series exhibits a skewness value of 1.2542109283425018 and a kurtosis value of 0.5034744543991527. The Fractal dimension analysis yields a value of -0.7188499404935836, indicating a Complex and irregular time-series structure. The dataset is converted into a simple regression task by extracting the previously described features.\n\n### RESPONSE:\nXGBoostRegressor']

# %%
test_responses=[]
# get all test data inference result
for test_prompt in test_dataset['text']:
  inputs= tokenizer(
  [test_prompt], return_tensors = "pt").to("cuda")

  outputs = model.generate(**inputs, max_new_tokens = 5, use_cache = True)
  test_responses.append(tokenizer.batch_decode(outputs))

# %%
# Convert the dataset to a Pandas DataFrame
df = test_dataset.to_pandas()
df['model_responses']= test_responses
df.to_csv('test_model_result_unsloth.csv', index=False)

# %%
predictions = []
for response in test_responses:
    result = response[0].split('\n\n### RESPONSE:')[1].split('</s>')[0].strip()
    result = result.replace('\n', '').replace('.', '')  # Remove \n and .
    if result == '<eos>LIGHTgbmRegressor':
        result = '<eos>LightgbmRegressor'
    elif result == '<eos>ADABoostRegressor':
        result = '<eos>AdaboostRegressor'

    predictions.append(result)

predictions
# Out:
# ['XGBoostRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'ExtraTreesRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'ExtraTreesRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'RandomForestRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'LassoRegressor',
#  'RandomForestRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'ExtraTreesRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'ExtraTreesRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'RandomForestRegressor',
#  'ExtraTreesRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'RandomForestRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'ElasticNetRegressor',
#  'RandomForestRegressor',
#  'ExtraTreesRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'GaussianProcessRegressor',
#  'ExtraTreesRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'ExtraTreesRegressor',
#  'ExtraTreesRegressor',
#  'ElasticNetRegressor',
#  'GaussianProcessRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'ExtraTreesRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'LightgbmRegressor',
#  'RandomForestRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'RandomForestRegressor',
#  'AdaboostRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'RandomForestRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'ExtraTreesRegressor',
#  'RandomForestRegressor',
#  'ExtraTreesRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'RandomForestRegressor',
#  'GaussianProcessRegressor',
#  'XGBoostRegressor',
#  'ExtraTreesRegressor',
#  'ElasticNetRegressor',
#  'RandomForestRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'ExtraTreesRegressor',
#  'RandomForestRegressor',
#  'ExtraTreesRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ExtraTreesRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'RandomForestRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ExtraTreesRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'ExtraTreesRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ExtraTreesRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'GaussianProcessRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'RandomForestRegressor',
#  'RandomForestRegressor',
#  'ElasticNetRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'ExtraTreesRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'ExtraTreesRegressor',
#  'ExtraTreesRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'LightgbmRegressor',
#  'ExtraTreesRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'RandomForestRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'ExtraTreesRegressor',
#  'RandomForestRegressor',
#  'ElasticNetRegressor',
#  'RandomForestRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'RandomForestRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'ExtraTreesRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'ExtraTreesRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'ExtraTreesRegressor',
#  'XGBoostRegressor',
#  'RandomForestRegressor',
#  'ExtraTreesRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'LightgbmRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'RandomForestRegressor',
#  'ExtraTreesRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'ExtraTreesRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'ExtraTreesRegressor',
#  'LassoRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'ExtraTreesRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ExtraTreesRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'ExtraTreesRegressor',
#  'RandomForestRegressor',
#  'ExtraTreesRegressor',
#  'ElasticNetRegressor',
#  'ExtraTreesRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'ExtraTreesRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'LassoRegressor',
#  'RandomForestRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'RandomForestRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'RandomForestRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'RandomForestRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'RandomForestRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'GaussianProcessRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'RandomForestRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'ExtraTreesRegressor',
#  'LassoRegressor',
#  'RandomForestRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'LightgbmRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'ExtraTreesRegressor',
#  'XGBoostRegressor',
#  'ExtraTreesRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'RandomForestRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'ExtraTreesRegressor',
#  'ElasticNetRegressor',
#  'RandomForestRegressor',
#  'RandomForestRegressor',
#  'RandomForestRegressor',
#  'RandomForestRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'ExtraTreesRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'LightgbmRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'RandomForestRegressor',
#  'ExtraTreesRegressor',
#  'ElasticNetRegressor',
#  'ExtraTreesRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'ExtraTreesRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'XGBoostRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'ExtraTreesRegressor',
#  'XGBoostRegressor',
#  'RandomForestRegressor',
#  'ExtraTreesRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'RandomForestRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'LightgbmRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'LassoRegressor',
#  'LightgbmRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'ExtraTreesRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ExtraTreesRegressor',
#  'ExtraTreesRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'RandomForestRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'RandomForestRegressor',
#  'ExtraTreesRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'ExtraTreesRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'RandomForestRegressor',
#  'XGBoostRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'ElasticNetRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'ExtraTreesRegressor',
#  'ElasticNetRegressor',
#  'ExtraTreesRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'LightgbmRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'ElasticNetRegressor',
#  'RandomForestRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'RandomForestRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'RandomForestRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'RandomForestRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'ExtraTreesRegressor',
#  'ElasticNetRegressor',
#  'RandomForestRegressor',
#  'ExtraTreesRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'RandomForestRegressor',
#  'ElasticNetRegressor',
#  'LassoRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'LassoRegressor',
#  'ElasticNetRegressor',
#  'XGBoostRegressor',
#  'RandomForestRegressor',
#  'LassoRegressor',
#  'ExtraTreesRegressor',
#  'LassoRegressor',
#  'XGBoostRegressor',
#  'LassoRegressor']

# %%
len(predictions)
# Out:
# 828

# %% [markdown]
# # run this only if the output of model contain the end tokenizer <eos>

# %%
import re

def extract_model_name(prediction):
    """
    Extract the model name from a prediction string using regex.
    Corrects 'ADABoostRegressor' to 'AdaBoostRegressor'.
    """
    # Adjust regex to match model names more precisely
    match = re.search(r"\b[A-Za-z]+(?:[A-Za-z0-9]*)\b", prediction)
    if match:
        model_name = match.group()
        return model_name
    return None  # Return None if no match is found

# Apply the extraction to all predictions
extracted_predictions = [extract_model_name(pred.split('<eos>')[-1].strip()) for pred in predictions]

# Print the extracted model names
print(extracted_predictions)

# %% [markdown]
# # continue testing

# %%
actual_data= df['algorithm']
len(actual_data)
# Out:
# 828

# %%
actual_data
# Out:
# 0              XGBoostRegressor
# 1           ExtraTreesRegressor
# 2         RandomForestRegressor
# 3                LassoRegressor
# 4         RandomForestRegressor
#                  ...
# 823            XGBoostRegressor
# 824           LightgbmRegressor
# 825           AdaboostRegressor
# 826         ElasticNetRegressor
# 827    GaussianProcessRegressor
# Name: algorithm, Length: 828, dtype: object

# %%
from sklearn.metrics import f1_score

# Assuming `predictions` and `actual_data` are lists or arrays of labels
f1 = f1_score(actual_data, predictions, average='micro')  # Use 'macro' or 'micro' as needed


print("F1 Score:", f1)
# Out:
# F1 Score: 0.2922705314009662

# %%
from sklearn.metrics import accuracy_score
# Calculate the accuracy
accuracy = accuracy_score(actual_data, predictions)

# Print the accuracy
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.2922705314009662

# %%
import mlflow
from mlflow.tracking import MlflowClient

# Set the tracking URI
mlflow.set_tracking_uri("https://78d5-35-226-137-11.ngrok-free.app")

# Initialize the MLflow client
client = MlflowClient()

# Specify the run ID
run_id = "e36e01a8e14a4fd6b272143744149d9c"

# Specify the artifact path
artifact_path = "unsloth_Llama_3.1_8B_Regression_Univariate"  # Adjust this path to your artifact's location

# Download the artifact
local_dir = "/"
client.download_artifacts(run_id, artifact_path, local_dir)

print(f"Artifacts downloaded to: {local_dir}")
# Out:
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[6], line 18
#      16 # Download the artifact
#      17 local_dir = "/"
# ---> 18 client.download_artifacts(run_id, artifact_path, local_dir)
#      20 print(f"Artifacts downloaded to: {local_dir}")
#
# File c:\Users\ziad.abdlhamed\AppData\Local\Programs\Python\Python312\Lib\site-packages\mlflow\tracking\client.py:2853, in MlflowClient.download_artifacts(self, run_id, path, dst_path)
#    2806 def download_artifacts(self, run_id: str, path: str, dst_path: Optional[str] = None) -> str:
#    2807     """
#    2808     Download an artifact file or directory from a run to a local directory if applicable,
#    2809     and return a local path for it.
#    (...)
#    2851         Artifacts: ['features.txt']
#    2852     """
# -> 2853     return self._tracking_client.download_artifacts(run_id, path, dst_path)
#
# File c:\Users\ziad.abdlhamed\AppData\Local\Programs\Python\Python312\Lib\site-packages\mlflow\tracking\_tracking_service\client.py:907, in TrackingServiceClient.download_artifacts(self, run_id, path, dst_path)
#     890 def download_artifacts(self, run_id, path, dst_path=None):
#     891     """Download an artifact file or directory from a run to a local directory if applicable,
#     892     and return a local path for it.
#     893
#    (...)
#     905
#     906     """
# --> 907     return self._get_artifact_repo(run_id).download_artifacts(path, dst_path)
#
# File c:\Users\ziad.abdlhamed\AppData\Local\Programs\Python\Python312\Lib\site-packages\mlflow\store\artifact\artifact_repo.py:302, in ArtifactRepository.download_artifacts(self, artifact_path, dst_path)
#     296         template = "##### File {path} #####\n{error}"
#     298     failures = "\n".join(
#     299         template.format(path=path, error=error, traceback=tracebacks[path])
#     300         for path, error in failed_downloads.items()
#     301     )
# --> 302     raise MlflowException(
#     303         message=(
#     304             "The following failures occurred while downloading one or more"
#     305             f" artifacts from {self.artifact_uri}:\n{_truncate_error(failures)}"
#     306         )
#     307     )
#     309 return os.path.join(dst_path, artifact_path)
#
# MlflowException: The following failures occurred while downloading one or more artifacts from https://78d5-35-226-137-11.ngrok-free.app/api/2.0/mlflow-artifacts/artifacts/314000315323789333/e36e01a8e14a4fd6b272143744149d9c/artifacts:
# ##### File unsloth_Llama_3.1_8B_Regression_Univariate #####
# API request to https://78d5-35-226-137-11.ngrok-free.app/api/2.0/mlflow-artifacts/artifacts/314000315323789333/e36e01a8e14a4fd6b272143744149d9c/artifacts/unsloth_Llama_3.1_8B_Regression_Univariate failed with exception HTTPSConnectionPool(host='78d5-35-226-137-11.ngrok-free.app', port=443): Max retries exceeded with url: /api/2.0/mlflow-artifacts/artifacts/314000315323789333/e36e01a8e14a4fd6b272143744149d9c/artifacts/unsloth_Llama_3.1_8B_Regression_Univariate (Caused by ResponseError('too many 500 error responses'))
